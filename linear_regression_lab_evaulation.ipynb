# %% [markdown]
# <a href="https://colab.research.google.com/github/sreesujit88/Lab-Evoulation-Linear-Regression-/blob/main/linear_regression_lab_evaulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Classifier

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
data = pd.read_csv("/content/FuelConsumption.csv")
# Out:
#      <input type="file" id="files-8f296b8b-550e-4e3d-af9c-96e0f29e2620" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f296b8b-550e-4e3d-af9c-96e0f29e2620">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving FuelConsumption.csv to FuelConsumption.csv

# %%
data
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
X = data.iloc[:,4:5].values
y = data.iloc[:, -1].values

# %%
print(X)
print(y)
# Out:
# [[2. ]
#  [2.4]
#  [1.5]
#  ...
#  [3. ]
#  [3.2]
#  [3.2]]
# [196 221 136 ... 271 260 294]

# %%
#training and test

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = .33,random_state = 50)

# %%
print(X_train)
# Out:
# [[2014 'MINI' 'COOPER PACEMAN' 'COMPACT']
#  [2014 'MERCEDES-BENZ' 'E 63 AMG 4MATIC' 'MID-SIZE']
#  [2014 'FORD' 'F150 FFV 4X4' 'PICKUP TRUCK - STANDARD']
#  ...
#  [2014 'BENTLEY' 'CONTINENTAL GT CONVERTIBLE' 'SUBCOMPACT']
#  [2014 'BMW' 'X6 M' 'SUV - STANDARD']
#  [2014 'BMW' '740Li xDRIVE' 'FULL-SIZE']]

# %%
print(y_train)
# Out:
# [[2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
# ...

# %%
print(X_test)
# Out:
# [[2014 'HYUNDAI' 'SONATA' 'FULL-SIZE']
#  [2014 'GMC' 'YUKON DENALI AWD' 'SUV - STANDARD']
#  [2014 'FORD' 'MUSTANG' 'SUBCOMPACT']
#  ...
#  [2014 'CHRYSLER' '300' 'FULL-SIZE']
#  [2014 'JEEP' 'GRAND CHEROKEE 4X4 DIESEL' 'SUV - STANDARD']
#  [2014 'INFINITI' 'Q70' 'MID-SIZE']]

# %%
print(y_test)
# Out:
# [[2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
#  [2014]
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
#train set
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Engine Size VS CO2 Emmition(Training Set)')
plt.xlabel('CO2 Emmition')
plt.ylabel('ENGINE SIZE')
plt.show()

# %%
#test set
plt.scatter(X_test,y_test,color='blue')
plt.plot(X_test,regressor.predict(X_test),color='red')
plt.title('EngineSize VS CO2EMMITION(Test Set)')
plt.xlabel('CO2EMMITION')
plt.ylabel('ENGINESIZE')
plt.show()

# %%
#user prediction
sal=int(input('Please Enter EngineSize: '))
prc = regressor.predict([[sal]])
print('The CO2Emmition should be {prc}')
# Out:
# Please Enter EngineSize: 25
# The CO2Emmition should be {prc}

# %%
#Accuracy
regressor.score(X_test,y_test)
# Out:
# 0.7379379977656382
